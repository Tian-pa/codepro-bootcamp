# %%
print('Hola mundo')
# Out:
# Hola mundo

# %% [markdown]
# ### Variables

# %%
# snake-case:
frase_famosa = "ma barata las patatas"

# %%
# Orden de ejecución:

fruta = "naranja"
print(fruta)

cantidad_de_frutas = 4
print(cantidad_de_frutas)

fruta = "banana" # cuando un dato es reemplazado por otro se le dice sobreescritura :)
print(fruta)
# Out:
# naranja
# 4
# banana

# %% [markdown]
# ### Tipos de datos

# %%
edad = 28 # --> Integer
altura = 1.80 # --> float
nombre = "Maggi" # --> String
feliz = True # --> Bool


# print(edad)
# print(altura)
# print(nombre)
# print(feliz)
# El modo de seleccionar todo para que sea comentario es seleccionarlo, presionar ctrl + k y ctrl + c

print(edad, altura, nombre, feliz)
# Out:
# 28
# 1.8
# Maggi
# True
# 28 1.8 Maggi True

# %% [markdown]
# ### El modo de seleccionar todo para que sea comentario es seleccionarlo, presionar ctrl + k y ctrl + c

# %% [markdown]
# ## Challenge 🤺
# ## Crea 3 variables con tu nombre, edad y ciudad. Imprime en una sola línea usando print()

# %%
# Segundo Challenge
nombre = "Elvio Nelson Sebastián Peralta Aguirre"
edad = 22
ciudad = "Caaguazú"

print("Mi nombre es", nombre + ",", "tengo", edad, "años de edad y vivo en la ciudad de", ciudad)
# Como se hace para que se pueda tener la coma más cerca del dato que queremos imprimir de una forma en específico
# Edit: Utilizamos la concatenación para poder sumarle uno o más símbolos a textos
# Out:
# Mi nombre es Elvio Nelson Sebastián Peralta Aguirre, tengo 22 años de edad y vivo en la ciudad de Caaguazú

# %% [markdown]
# # Reglas para nombrar variables (en material)

# %% [markdown]
# ## Operadores matemáticos

# %%
producto1 = "papas fritas"
costo_producto1 = 15000
producto2 = "coca cola"
costo_producto2 = 14000
capital = 50000
dolar = 6700

# Realizamos la suma
costo_total = costo_producto1 + costo_producto2
print("Precio total: ", costo_total)

# Realizamos la resta
vuelto = capital - costo_total
print("El vuelto es: ", vuelto)

# Realizamos la división
vuelto_dolar = vuelto / dolar
print(vuelto_dolar)

# TAREA :3 -- Qué significa el símbolo de porcentaje en programación
# TAREA :3 -- Cómo tener dos decimales en nuestra impresión
# Out:
# Precio total:  29000
# El vuelto es:  21000
# 3.1343283582089554

# %% [markdown]
# Challenge 🤺 - 10m
# Suma: asignar dos números en dos variables diferentes cantidad_de_manzanas y cantidad_de_naranjas. Luego sumar ambas variables en cantidad_de_frutas. Imprimir la última variable.
#
# Resta: asignar un valor numérico a la variable frutas_vendidas. Luego, asignar la resta entre cantidad_de_frutas y frutas_vendidas a la variable frutas_restantes. Imprimir la última variable.

# %%
# Challenge 3

# Suma

    # Variables
cantidad_de_manzanas = 10
cantidad_de_naranjas = 25

    # Operación
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print("La cantidad total de frutas es: ", cantidad_de_frutas)

# Resta

    # Variables
frutas_vendidas = 20

    # Operación
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print("La cantidad sobrante de frutas es: ", frutas_restantes)
# Out:
# La cantidad total de frutas es:  35
# La cantidad sobrante de frutas es:  15

# %% [markdown]
# # OjO Sebastián
# ### Para mandar tu código a discord, inicias con tres comillas (sin espacios) y terminas con tres comillas (sin espacios)

# %% [markdown]
# ### Concatenación

# %%
nombre = "Sebastián"
apellido = "Peralta"

print(nombre)
print(apellido)

# Formas de impresion con valores de texto

# Concatenar los strings
print(nombre + " " + apellido)

# Con una f al principio y corchetes 
print(f'Hola, me llamo {nombre}, y mi apellido es {apellido}')
# Out:
# Sebastián
# Peralta
# Sebastián Peralta
# Hola, me llamo Sebastián, y mi apellido es Peralta

# %% [markdown]
# ### Challenge 🤺 - 10m
# ### Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
# ### EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."

# %%
# Challenge 4
# Formas de concatenación
     
    # Variables
nombre = "Patricia"
apellido = "Molina"

    # Por signos aritméticos
print("Hola, buenas tardes, mi nombre es " + nombre + " " + apellido + " y soy participante de CodePro")

    # Por f-string.
print(f'Buenas tardes, mi nombre es {nombre} {apellido} y soy participante de CodePro.')
# Out:
# Hola, buenas tardes, mi nombre es Patricia Molina y soy participante de CodePro
# Buenas tardes, mi nombre es Patricia Molina y soy participante de CodePro.

# %% [markdown]
# # Input baby

# %%
nombre = input("Escribi tu nombre: ")
print(nombre)
# Out:
# Sebastián

# %%
# Solicitar al usuario un producto
producto = input("¿Qué producto te gustaría adquirir?")
print(f'El producto que el cliente desea es: {producto}')

cantidad_de_productos = input("¿Qué cantidad te gustaría de dicho producto?")
print(f'La cantidad que el cliente desea es: {cantidad_de_productos}')
# Out:
# El producto que el cliente desea es: Bananas
# La cantidad que el cliente desea es: 10

# %% [markdown]
# # Ver tipos de datos

# %%
edad = 19
print(type(edad))

nombre = "Claudia"
print(type(nombre))

temperatura = 36.5
print(type(temperatura))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
edad = input("¿Cuántos años tienes?")
print(type(edad))

cantidad_de_anhos = int(edad)
print(type(cantidad_de_anhos))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### Challenge 🤺 - 8m
# ### Solicitar al usuario ingresar dos números y almacenarlos en dos variables. Luego, imprimir la suma de los dos números.

# %%
# Challenge 5

# Pedimos los dos números al usuario:
numero1 = int(input("Ingrese un número: "))
numero2 = int(input("Ingrese otro número: "))

# Realizamos la operación:
# suma = numero1 + numero2

# Imprimimos la respuesta:
print("La suma de los números es:", numero1 + numero2)

# Por CONVENCIÓN las variables siempre son en minúscula.
# Out:
# La suma de los números es: 12

# %% [markdown]
# ### ¿Qué es un algoritmo?

# %% [markdown]
# ### Funciones

# %%
# Acá definimos la función
def preparar_sandwich(): #Definiendo la función babyy
    print("Preparar un sandwich: ")
    print("Ya el sandwich está casi listo")
# Aquí termina la función

# Acá le llamamos a la función
preparar_sandwich()
# Out:
# Preparar un sandwich:
# Ya el sandwich está casi listo

# %% [markdown]
# ### Challenge 🤺 - 10m
# ### Crear una función de un proceso que se les ocurra que tenga varios pasos.
#
# ### Ejecutar la función 3 veces.

# %%
# Challenge 6

# Definimos la función hacer_challenge
def hacer_challenge():
    print("\nIdentificamos los parámetros del challenge")
    print("Empezamos a codear")
    print("Terminamos el challenge")
# Acá termina el proceso de realización del challenge

# Inicia el proceso:
print("¡¡Maggi ha mandado el primer challenge al discord!!")

# Primer llamado a la función
hacer_challenge()

print("\n¡¡Maggi ha mandado el segundo challenge al discord!!")

# Segundo llamado a la función
hacer_challenge()

print("\n¡¡Maggi ha mandado el tercer y último challenge al discord!!")

# Tercer llamado a la función
hacer_challenge()

# %% [markdown]
# ### Funciones con parámetros y argumentos:
# Cuando hablamos de parámetro, se trata de lo que ponemos dentro de la función.
# Cuando hablamos de argumento, se trata del dato que le asignamos a la variable de la función.
# (Investigar bien las diferencias entre cada uno!!!)

# %%
# Definimos una función con el parametro "ingresiente"
def preparar_sandwich(ingrediente):
    print(f"Preparar sandwich de {ingrediente}")

#Ejecutar la funcion con el argumento
preparar_sandwich("pollo")
preparar_sandwich("milanesa")
preparar_sandwich("atún")

ingrediente1 = "milanesa"
ingrediente2 = "pollo"

                     # Acá están los parámetros
def preparar_sandwich(ingrediente1, ingrediente2):
    print(f"Preparar sandwich de {ingrediente1} con {ingrediente2}")

                  # Acá son los argumentos
preparar_sandwich(ingrediente1, ingrediente2)
# Out:
# Preparar sandwich de pollo
# Preparar sandwich de milanesa
# Preparar sandwich de atún
# Preparar sandwich de milanesa con pollo

# %% [markdown]
# ### Challenge 7
# Escribir una función que nos pregunte las características de un elemento a comprar e imprima el elemento con sus características.

# %%
# Challenge 7

# Definimos la función

def consulta_elementos(elemento1, elemento2, elemento3):
    print("--- ELEMENTOS QUE DESCRIBEN AL PRODUCTO ---\n")
    print("El primer elemento descrito es: ", elemento1)
    print("El segundo elemento descrito es: ", elemento2)
    print("El tercer elemento descrito es: ", elemento3)
# Acá termina la función

# Preguntamos al usuario cuáles son los elementos para describir el producto que desea comprar
elemento1 = input("Describe el primer elemento del producto que deseas: ")
elemento2 = input("Describe el segundo elemento del producto que deseas: ")
elemento3 = input("Describe el tercer elemento del producto que deseas: ")

# Enviamos los argumentos a la función para que los utilice
consulta_elementos(elemento1, elemento2, elemento3)
# Out:
# --- ELEMENTOS QUE DESCRIBEN AL PRODUCTO ---
#
# El primer elemento descrito es:  Toyota
# El segundo elemento descrito es:  Hillux
# El tercer elemento descrito es:  Verde

# %% [markdown]
# ### Funciones Built-in o predefinidas vs funciones personalizadas :D

# %% [markdown]
# ### Alcance (SCOPE)

# %%
# NOTAS!!!
# Los elementos de alcance global son los que son accesibles para todas las lineas de código
# Los elementos de alcance local son los que son accesibles únicamente a alguna líneas del código
# Cuando una variable está fuera de una función, es una variable global
# Cuando una variable está dentro de una función, es una variable local
# Por convención, las variables que están totalmente en mayúsculas son aquellas que no serán sobreescritas a lo largo de todo el código

# %% [markdown]
# ### Challenge 🤺 - 10m
# ### 🎯 Objetivo:
# ### Escribir una función que pregunte por las características de un producto a comprar (por ejemplo, tipo, tamaño, color) e imprima un resumen de ese producto con las características ingresadas.
#
# ### Además, deben trabajar con variables locales y globales.

# %%
# Challenge 8

# --- Variables globales
bienvenida = "¡¡Bienvenido a la tienda del Pericon!!"

# Definimos la función que imprime las características:
def impresion_caracteristicas_producto(producto, tipo_producto, tamaño_producto, color_producto):
    print("El producto es: ", producto)
    print("El tipo de producto es: ", tipo_producto)
    print("El tamaño del producto es: ", tamaño_producto)
    print("El color del producto es: ", color_producto)
          

# Acá termina la función de impresión

# Definimos la función que pregunta las características del producto:
def pregunta_características_producto():
    print(bienvenida)
    producto = input("¿Cuál es el producto que desea comprar? ")
    tipo_producto = input("¿De qué tipo es?" )
    tamaño_producto = input("¿De qué tamaño es?" )
    color_producto = input("¿De qué color es?" )

    impresion_caracteristicas_producto(producto, tipo_producto, tamaño_producto, color_producto)
# Acá termina la definición del producto

# Inicia el proceso de descripción del producto.
pregunta_características_producto()
# Out:
# ¡¡Bienvenido a la tienda del Pericon!!
# El producto es:
# El tipo de producto es:
# El tamaño del producto es:
# El color del producto es:
