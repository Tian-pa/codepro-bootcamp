# %%
print("Hola Mundo Baby")
# Out:
# Hola Mundo Baby

# %%
def suma(n1, n2):
    print("El resultado de la suma es: ", n1 + n2)

numero1 = int(input("Dame un número: "))
numero2 = int(input("Dame otro número: "))

suma(numero1, numero2)
# Out:
# El resultado de la suma es:  20

# %% [markdown]
# # Challenge 16
#
# ### Crear una variable para las letras que reciban dos letras y que verifique si son iguales
#
# ### Una condición en la que si son iguales muestre un mensaje
# ### otra en la que si no lo son, también muestre

# %%
# Challenge 16

# Crear una variable para las letras que reciban dos letras y que verifique si son iguales

# Una condición en la que si son iguales muestre un mensaje
# otra en la que si no lo son, también muestre

# Se pide la primera letra al usuario.
letra1 = input("Escriba una letra: ")

# Se imprime la primera letra ingresada
print("La primera letra ingresada fue: ", letra 1)

# Se pide la segunda letra al usuario.
letra2 = input("Estriba otra letra: ")

# Se imprime la segunda letra ingresada
print("La segunda letra ingresada fue: ", letra 1)

# Función que compara las letras
def verificador_de_letras(letra1, letra2):

    # Condicional realiza la comparación
    if letra1 == letra2:
        print("¡Las letras son iguales!")
    else:
        print("¡Las letras son distintas :c!")

# Se invoca a la función
verificador_de_letras(letra1, letra2)
# Out:
# ¡Las letras son distintas :c!

# %% [markdown]
# # Return baby - nueva palabra asignada adquirida!
#
# En síntesis, una de las propiedades del return es que, por ejemplo, cuando normalmente dentro de una función tendríamos un print, el return puede imprimir el mensaje y puede devolver un tipo de dato del tipo int
# Te devuelve el valor que la función está obteniendo!!!

# %%
def sumar(n1, n2):
    resultado_suma = n1 + n2
    return resultado_suma

print(type(sumar(2,2)))

resultado = sumar(5, 8)
print(resultado)
print(sumar(5,10))
# Out:
# <class 'int'>
# 13
# 15

# %% [markdown]
# ## Challenge 3 🤺 - 15m
# ## Crear una función que reciba dos parámetros (una palabra y un número), y que retorne True si el número es igual a la cantidad de letras de la palabra. En caso contrario, que retorne False.
#
# ## Pista: cantidad de letras de una palabra en python

# %%
# Challenge 17

# Función de comparador de palabra y número
def comparador_palabra_numero(palabra, numero):
    # Si la cantidad de letras de la palabra coincide con el número ingresado
    if len(palabra) == numero:
        # Devuelve True
        return True
    else:
        # Sino, devuelve False
        return False

# Le pedimos al usuario que ingrese una palabra
palabra = input("Dame una palabra: ")

# Le pedimos al usuario que ingrese un número
numero = int(input("Dame un número: "))

# Invocamos a la función
comparador_palabra_numero(palabra, numero)

# Necesito que los espacios no cuenten como letras
# Necesito que cuando yo le dé el numero, los espacios no cuenten como cantidad de letra
# Out:
# True

# %%
palabra = len("matraca")

print(palabra)

line = line.translate(None, '!@#$')
# Out:
# 7

# %% [markdown]
# # Challenge 18
#
# ### Challenge 4 🤺 - 20 min
# ### Crear función que revise si una palabra contiene una letra. En caso de que la contenga, retornar la letra entre corchetes []. De lo contrario, retornar solo la letra.

# %%
# Challenge 18

# Definimos la función para encontrar la letra en una palabra
def encontrar_letra_en_palabra(palabra, letra):
    # Si la letra se encuentra en la palabra, se imprime la letra entre corchetes
    if letra in palabra:
        return f"[{letra}]"
    # Si la letra no se encuentra en la palabra, se imprime la letra sóla.
    else:
        return f"{letra}"

# Pedimos al usuario qué palabra le gustaría analizar
palabra = input("Ingrese una palabra: ")

# Imprimimos la palabra elegida
print("La palabra elegida es: ", palabra)

# Pedimos al usuario que no de una letra
letra = input("Ingrese una letra: ")

# Imprimimos la letra elegida
print("La letra elegida es: ", letra)

# Invocamos la función
encontrar_letra_en_palabra(palabra, letra)
# Out:
# La palabra elegida es:  palabra
# La letra elegida es:  a
# '[a]'

# %% [markdown]
# # Challenge 19
#
# ### Challenge 5 🤺 - 20m
# Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con list(). Agregar esa lista de caracteres a una lista llamada palabras_ingresadas. Repetir el proceso 3 veces. Cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas.
#
#
# Ejemplo del resultado esperado:
#
# [['c', 'i', 'e', 'l', 'o']]
#  # Al ingresar la primera palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
#  # Al ingresar la segunda palabra
#
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]
#  # Al ingresar la tercera palabra

# %%
# Challenge 19

### Investigado con Google ###
# palabra = "Python"
# lista_caracteres = list(palabra)
# print(f"Lista de caracteres: {lista_caracteres}") # Salida: ['P', 'y', 't', 'h', 'o', 'n']

# Pedimos al usuario que ingrese una palabra
palabra = input("Ingrese una palabra, por favor: ")

# La palabra se convierte en una lista por la palabra asignada list
lista_de_palabras = list(palabra)

# La palabra convertida en lista, pasa a ser parte la nueva lista, palabras_ingresadas
palabras_ingresadas = [lista_de_palabras]

# Imprimimos la palabra ingresada en la lista
print(palabras_ingresadas)

# Pedimos al usuario la siguiente palabra
palabra = input("Ingrese otra palabra, por favor: ")

# La palabra se convierte en una lista nuevamente
lista_de_palabras = list(palabra)

# La palabra hecha lista, ahora forma parte de la lista anteriormente creada
palabras_ingresadas.append(lista_de_palabras)

# Imprimimos las palabras ingresadas hasta ahora
print(palabras_ingresadas)

# Le pedimos al usuario que ingrese una palabra una última vez
palabra = input("Ingrese una última palabra, por favor: ")

# La palabra se convierte en una lista nuevamente
lista_de_palabras = list(palabra)

# La palabra hecha lista, ahora forma parte de la lista anteriormente creada
palabras_ingresadas.append(lista_de_palabras)

# Finalmente, se imprime la lista completa de palabas ingresadas
print(palabras_ingresadas)
# Out:
# [['c', 'a', 's', 'a']]
# [['c', 'a', 's', 'a'], ['m', 'a', 's', 'a']]
# [['c', 'a', 's', 'a'], ['m', 'a', 's', 'a'], ['p', 'e', 'r', 'a']]

# %%
# Challenge 19 -- Hecho por Maria Paz (Mu bueno)

# Definir una variable palabra = input()
# Convertir palabra a lista con lista_de_palabra = list(palabra)
# Creamos otra lista llamada: palabras_ingresadas = []
# palabras_ingresadas.append(lista_de_palabra)
# Probar un bucle que repita 3 veces el proceso seguiente: 

palabras_ingresadas = []
for i in range(3):
    palabra = input("Ingresar palabra")
    lista_usuario = list(palabra)
    palabras_ingresadas.append(lista_usuario)
    print(palabras_ingresadas)

# %% [markdown]
# Challenge 6 (20)🤺 - 20m
#
# Dada la lista de ejemplo:
#
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#
# Crear una función que imprima una grilla (lista de listas), una línea por cada lista dentro de la lista principal.
#
# Ejemplo del resultado esperado:
#
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
# Challenge 20

# Definimos nuestra lista con sus respectivos elementos
lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

# Definimos nuestra función que imprimirá los elementos de nuestra lista
def impresion_grilla():
    # Se imprimirán los tres elementos de la lista
    for i in range(3):
        print("Valor del iterador en esta vuelta: ", i)
        # Se imprime el elemento con el valor del iterador del for
        print(lista[i])

# Se invoca a la función
impresion_grilla()
# Out:
# Valor del iterador en esta vuelta:  0
# ['h', 'o', 'l', 'i', 's']
# Valor del iterador en esta vuelta:  1
# ['h', 'e', 'l', 'l', 'o']
# Valor del iterador en esta vuelta:  2
# ['h', 'a', 'l', 'l', 'o']

# %%
# Challenge 20 -- Hecho por Juan Vicente

lista=[['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
def dar_enter():
    for i in lista:
        print(f"{i}\n")
dar_enter()
# Out:
# ['h', 'o', 'l', 'i', 's']
#
# ['h', 'e', 'l', 'l', 'o']
#
# ['h', 'a', 'l', 'l', 'o']

# %% [markdown]
# # Funición Verificadora

# %%
letras_verificadas = []
cantidad_letras = 5

def verificador_palabra(palabra_ingresada, palabra_secreta):
    for i in range(cantidad_letras):
        las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta[i] # True o False
        la_letra_existe_en_la_palabra = palabra_ingresada[i] in palabra_secreta 
        
        if las_palabras_son_iguales:
            letras_verificadas.append(f"[{palabra_ingresada[i]}]")
        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append(f"({palabra_ingresada[i]})")
        else:
            letras_verificadas.append(palabra_ingresada[i])
    
    return letras_verificadas

verificador_palabra('holas', 'calor')
# Out:
# ['h', '(o)', '[l]', '(a)', 's']

# %%
# definir la cantidad de intentos = variable
intentos = 0

while intentos < 6:
    print(f"te quedan {6 - intentos} intentos")
    intentos = intentos + 1
    palabra_ingresada = input("Ingrese una palabra")
    print(f"la palabra ingresada es: {palabra_ingresada}")
# Out:
# te quedan 6 intentos
# la palabra ingresada es:
# te quedan 5 intentos
# la palabra ingresada es:
# te quedan 4 intentos
# la palabra ingresada es:
# te quedan 3 intentos
# la palabra ingresada es:
# te quedan 2 intentos
# la palabra ingresada es:
# te quedan 1 intentos
# la palabra ingresada es:
